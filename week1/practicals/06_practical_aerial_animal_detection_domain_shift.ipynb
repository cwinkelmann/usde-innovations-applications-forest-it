# %%
# Illustrate that megadetector v5a performs worse on aerial images than v1000
# use the Eikelboom dataset for this, since it has a mix of aerial and ground images
# Show that SAHI is not making it better
